# %%
import pandas as pd

# %%
summary_df = pd.DataFrame({
    "Category": [
        "Repository",
        "Dataset",
        "OpenNeuro ID",
        "Track",
        "Primary Use",
        "Status"
    ],
    "Value": [
        "vestibular-network_repo1",
        "ID1000 (AOMIC)",
        "ds003097",
        "Vestibular Network",
        "Dataset readiness and feasibility",
        "Complete"
    ]
})

summary_df
# Out:
#        Category                              Value
# 0    Repository           vestibular-network_repo1
# 1       Dataset                     ID1000 (AOMIC)
# 2  OpenNeuro ID                           ds003097
# 3         Track                 Vestibular Network
# 4   Primary Use  Dataset readiness and feasibility
# 5        Status                           Complete

# %%
justification = [
    "The dataset is openly accessible and practical for immediate workflow development.",
    "It contains resting-state fMRI suitable for intrinsic connectivity analyses.",
    "Healthy participants support individual-differences questions.",
    "Multimodal MRI expands future analytical options.",
    "Vestibular systems can be operationalized through literature-derived ROIs.",
    "This repository focuses on readiness rather than final causal claims."
]

for j in justification:
    print("-", j)
# Out:
# - The dataset is openly accessible and practical for immediate workflow development.
# - It contains resting-state fMRI suitable for intrinsic connectivity analyses.
# - Healthy participants support individual-differences questions.
# - Multimodal MRI expands future analytical options.
# - Vestibular systems can be operationalized through literature-derived ROIs.
# - This repository focuses on readiness rather than final causal claims.

# %%
limitations = [
    "Dataset is not explicitly vestibular-labelled.",
    "Direct vestibular behavioral measures may be limited.",
    "Future repositories may require additional datasets for stronger task specificity."
]

for l in limitations:
    print("-", l)
# Out:
# - Dataset is not explicitly vestibular-labelled.
# - Direct vestibular behavioral measures may be limited.
# - Future repositories may require additional datasets for stronger task specificity.

# %%
future_df = pd.DataFrame({
    "Next Repository": [
        "vestibular-network_repo2-network-topology-variability",
        "vestibular-network_repo3-spatial-cognition-mapping",
        "vestibular-network_repo4-predictive-modelling",
        "vestibular-network_repo5-reproducibility-analysis"
    ],
    "Focus": [
        "Inter-individual network variability",
        "Network features and spatial cognition",
        "Prediction from connectivity features",
        "Robustness across analytical choices"
    ]
})

future_df
# Out:
#                                      Next Repository  \
# 0  vestibular-network_repo2-network-topology-vari...
# 1  vestibular-network_repo3-spatial-cognition-map...
# 2      vestibular-network_repo4-predictive-modelling
# 3  vestibular-network_repo5-reproducibility-analysis
#
#                                     Focus
# 0    Inter-individual network variability
# 1  Network features and spatial cognition
# 2   Prediction from connectivity features
# 3    Robustness across analytical choices

# %%
print("Notebook 5 complete.")
print("Repository establishes a justified starting point for vestibular-network research.")
# Out:
# Notebook 5 complete.
# Repository establishes a justified starting point for vestibular-network research.
