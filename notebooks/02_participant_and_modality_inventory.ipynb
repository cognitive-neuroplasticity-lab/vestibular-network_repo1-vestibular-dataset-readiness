# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
modalities = pd.DataFrame({
    "Modality": [
        "T1-weighted MRI",
        "Diffusion MRI",
        "Resting-state fMRI",
        "Task fMRI",
        "Behavioral / Psychometric Data"
    ],
    "Use for Vestibular Track": [
        "Anatomical ROI definition",
        "White-matter pathways",
        "Intrinsic network connectivity",
        "Task-related extensions",
        "Brain-behavior relationships"
    ]
})

modalities
# Out:
#                          Modality        Use for Vestibular Track
# 0                 T1-weighted MRI       Anatomical ROI definition
# 1                   Diffusion MRI           White-matter pathways
# 2              Resting-state fMRI  Intrinsic network connectivity
# 3                       Task fMRI         Task-related extensions
# 4  Behavioral / Psychometric Data    Brain-behavior relationships

# %%
participants = pd.DataFrame({
    "Criterion": [
        "Healthy cohort",
        "Normative sample",
        "Suitable for variability analyses",
        "No clinical confound focus",
        "Good for network neuroscience"
    ],
    "Status": ["Yes"] * 5
})

participants
# Out:
#                            Criterion Status
# 0                     Healthy cohort    Yes
# 1                   Normative sample    Yes
# 2  Suitable for variability analyses    Yes
# 3         No clinical confound focus    Yes
# 4      Good for network neuroscience    Yes

# %%
uses = pd.DataFrame({
    "Future Analysis": [
        "Vestibular ROI connectivity",
        "Graph theory metrics",
        "Spatial cognition prediction",
        "Structure-function coupling",
        "Reproducibility testing"
    ],
    "Feasible": ["Yes"] * 5
})

uses
# Out:
#                 Future Analysis Feasible
# 0   Vestibular ROI connectivity      Yes
# 1          Graph theory metrics      Yes
# 2  Spatial cognition prediction      Yes
# 3   Structure-function coupling      Yes
# 4       Reproducibility testing      Yes

# %%
print("Notebook 2 complete.")
print("Core modalities and participant suitability documented.")
# Out:
# Notebook 2 complete.
# Core modalities and participant suitability documented.
