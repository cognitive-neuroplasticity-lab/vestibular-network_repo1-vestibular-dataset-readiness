# %%
import pandas as pd

# %%
overview = pd.DataFrame({
    "Field": [
        "Dataset Name",
        "Collection",
        "OpenNeuro ID",
        "Population",
        "Primary Type",
        "MRI Modalities",
        "Behavioral Data",
        "Accessibility",
        "Use in This Repo"
    ],
    "Value": [
        "ID1000",
        "AOMIC",
        "ds003097",
        "Healthy adults",
        "Normative multimodal MRI dataset",
        "T1, DWI, Resting-state fMRI, Task fMRI",
        "Yes",
        "Public",
        "Vestibular-network readiness and feasibility"
    ]
})

overview
# Out:
#               Field                                         Value
# 0      Dataset Name                                        ID1000
# 1        Collection                                         AOMIC
# 2      OpenNeuro ID                                      ds003097
# 3        Population                                Healthy adults
# 4      Primary Type              Normative multimodal MRI dataset
# 5    MRI Modalities        T1, DWI, Resting-state fMRI, Task fMRI
# 6   Behavioral Data                                           Yes
# 7     Accessibility                                        Public
# 8  Use in This Repo  Vestibular-network readiness and feasibility

# %%
reasons = [
    "Large healthy sample suitable for individual-differences analyses",
    "Resting-state fMRI enables intrinsic connectivity mapping",
    "Structural MRI supports anatomical ROI work",
    "Behavioral measures increase cognitive relevance",
    "Public accessibility supports reproducible workflows",
    "Appropriate for secondary vestibular-network operationalization"
]

for r in reasons:
    print("-", r)
# Out:
# - Large healthy sample suitable for individual-differences analyses
# - Resting-state fMRI enables intrinsic connectivity mapping
# - Structural MRI supports anatomical ROI work
# - Behavioral measures increase cognitive relevance
# - Public accessibility supports reproducible workflows
# - Appropriate for secondary vestibular-network operationalization

# %%
limitations = [
    "Dataset is not explicitly vestibular-labelled",
    "Vestibular constructs must be operationalized using literature-derived ROIs",
    "Specific spatial tasks may need supplemental datasets later"
]

for l in limitations:
    print("-", l)
# Out:
# - Dataset is not explicitly vestibular-labelled
# - Vestibular constructs must be operationalized using literature-derived ROIs
# - Specific spatial tasks may need supplemental datasets later

# %%
roi_df = pd.DataFrame({
    "Candidate Region": [
        "Temporo-parietal junction",
        "Posterior insula",
        "Inferior parietal lobule",
        "Precuneus",
        "Hippocampus",
        "Parahippocampal cortex"
    ],
    "Relevance": [
        "Multisensory vestibular integration",
        "Core vestibular cortical processing",
        "Spatial orientation",
        "Self-location / imagery",
        "Navigation / spatial memory",
        "Scene and spatial context"
    ]
})

roi_df
# Out:
#             Candidate Region                            Relevance
# 0  Temporo-parietal junction  Multisensory vestibular integration
# 1           Posterior insula  Core vestibular cortical processing
# 2   Inferior parietal lobule                  Spatial orientation
# 3                  Precuneus              Self-location / imagery
# 4                Hippocampus          Navigation / spatial memory
# 5     Parahippocampal cortex            Scene and spatial context

# %%
verdict = pd.DataFrame({
    "Criterion": [
        "Accessible now",
        "Resting-state available",
        "Healthy cohort",
        "Behavioral relevance",
        "ROI feasibility",
        "Good starting dataset"
    ],
    "Status": ["Yes"] * 6
})

verdict
# Out:
#                  Criterion Status
# 0           Accessible now    Yes
# 1  Resting-state available    Yes
# 2           Healthy cohort    Yes
# 3     Behavioral relevance    Yes
# 4          ROI feasibility    Yes
# 5    Good starting dataset    Yes

# %%
print("Notebook 1 complete.")
print("Dataset selected: ID1000 / AOMIC")
print("Use case: Vestibular-network readiness and feasibility")
# Out:
# Notebook 1 complete.
# Dataset selected: ID1000 / AOMIC
# Use case: Vestibular-network readiness and feasibility
